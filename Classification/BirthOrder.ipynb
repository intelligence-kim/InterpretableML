# %%
# !pip install machine_learning_datasets
# !pip install opencv-python==4.5.3.56
# !pip install pdpbox

# %% [markdown]
# # 해석 방법론 (피처 중요도)
# 1. sklearn 모델의 고유 매개변수를 사용한 피처 중요도
# 2. 순열 피처 중요도 (PFI)
# 3. 부분 의존도 플롯 해석 (PDP)
# 4. 개별 조건부 기대치 (ICE)
#
# # Mission
# 1. 설문의 답과 출생 순서 사이의 관계
# 2. 그들의 경험적 연구에 사용할 수 있는 질문이 존재하는가
#
# ## Domain
# 형제자매 간의 역학 그리고 출생 순서에 따른 양육 방식이 성격에 어떠한 영향을 미치는가?
# - 프랜시스 골턴 : 첫째 아이를 더 높은 지능과 연관
# - 브램 분크 : 막내와 질투를 연관
# 다양한 이론들이 존재하지만 문화간의 차이가 아주 중요하기 때문에 서구 이론은 다른 지역에 잘 통하지 않는다.
# <br>
# 범주는 총 3가지
#     1. 첫째
#     2. 둘째 (첫째도 아니고 막내도 아닌 위치)
#     3. 막내
#
# ## Approch
# - 모델의 고유 매개변수를 사용해 모델에 가장 큰 영향을 미치는 피처를 찾는다. (글로벌 모듈러 해석 방법론)
# - PFI를 통한 더욱 신뢰성 있는 피처 중요도 탐색
# - PDP를 사용해 가장 중요한 피처가 결과에 미치는 한계 효과 포착
# - ICE 플롯을 사용해 개별 피처가 모델의 예측에 미치는 영향을 좀 더 세분화해서 시각화

# %% [markdown]
# ## 데이터 딕셔너리
# ### 인구 통계학적 피처처
# - age : 서수형. 참가자의 연 나이
# - engnat : 이진 값. 영어가 모국어인지 여부. 1=예, 2=아니요
# - gender : 범주형. 성별. 남서으 여성, 기타, 정의되지 않음
# - birth : 서수형. 부모가 낳은 총 자녀 수. 1~10, 11=기타
# - country: 범주형. 참가자의 국가. 2자리 코드
# - birthorder : 서수형. 목표변수인 출생 순서. 1:첫째,2:중간,3:막내
# ### 기술적 피처
# - source : 범주형. 성격 테스트에 도달한 방법. 1:구글에서 직접, 2:웹사이트 첫 페이지, 3:기타
# - screensize : 서수형. 테스트에 사요된 화면 크기. 2:600픽셀 이상, 1:그보다 작음
# - introelapse : 연속형. 성격 테스트 랜딩 페이지에서 보낸 시간(초)
# - testelapse : 연속형. 성격 테스트 본문에 소요된 시간(초)
# - endelapse : 연속형. 성격 테스트 종료 페이지에서 보낸 시간(초)

# %%
import math
import machine_learning_datasets as mldatasets
import pandas as pd
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics, linear_model, tree, discriminant_analysis,ensemble, neural_network, inspection
import matplotlib.pyplot as plt
from pdpbox import pdp
from pycebox.ice import ice, ice_plot
# Out:
# /home/studio/anaconda3/envs/ml/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
birthorder_df = mldatasets.load("personality-birthorder", prepare=True)
# Out:
# https://openpsychometrics.org/_rawdata/FBPS-ValidationData.zip downloaded to /home/studio/바탕화면/ml/Classification/data/FBPS-ValidationData.zip
# /home/studio/바탕화면/ml/Classification/data/FBPS-ValidationData.zip uncompressed to /home/studio/바탕화면/ml/Classification/data/FBPS-ValidationData
# 1 dataset files found in /home/studio/바탕화면/ml/Classification/data/FBPS-ValidationData folder
# parsing /home/studio/바탕화면/ml/Classification/data/FBPS-ValidationData/FBPS-ValidationData/FBPS-ValidationData.csv

# %%
birthorder_df.shape
# Out:
# (25813, 97)

# %% [markdown]
# - 출생 순서 칼럼 : y / 그 외 : X

# %%
rand = 9
y = birthorder_df['birthorder']
X = birthorder_df.drop(['birthorder'], axis=1).copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=rand)

# %% [markdown]
# - 의사 결정 트리, 그래디언 부스트 트리, 랜덤 포레스트, 로지스틱 회귀, 다층 퍼셉트론,LDA 여섯 가지 모델에 적합

# %%
class_models = {  
        #Tree
        'decision_tree':{'model': tree.\
                         DecisionTreeClassifier(max_depth=6, random_state=rand,\
                                                class_weight='balanced')},
        #Ensemble Methods
        'gradient_boosting':{'model':ensemble.\
                             GradientBoostingClassifier(n_estimators=200,\
                                                        max_depth=4, subsample=0.5,\
                                                        learning_rate=0.05)},
        'random_forest':{'model':ensemble.\
                         RandomForestClassifier(max_depth=11, n_estimators=300,\
                                                max_features='sqrt', random_state=rand)},
        #Generalized Linear Models (GLMs)
        'logistic':{'model': linear_model.\
                    LogisticRegression(multi_class='ovr', solver='lbfgs',\
                                       class_weight='balanced', max_iter=500)},
        #Discriminant Analysis
        'lda':{'model':discriminant_analysis.\
               LinearDiscriminantAnalysis(n_components=2)},
        #Neural Networks
        'mlp':{'model':make_pipeline(StandardScaler(), neural_network.\
                                     MLPClassifier(hidden_layer_sizes=(11,),\
                                                   early_stopping=True, random_state=rand,\
                                                   validation_fraction=0.25, max_iter=500))}
    }

# %%
for model_name in class_models.keys():
    fitted_model = class_models[model_name]['model'].fit(X_train, y_train) 
    y_train_pred = fitted_model.predict(X_train)
    y_test_pred = fitted_model.predict(X_test)
    class_models[model_name]['fitted'] = fitted_model
    class_models[model_name]['preds'] = y_test_pred
    class_models[model_name]['Accuracy_train'] =\
        metrics.accuracy_score(y_train, y_train_pred)
    class_models[model_name]['Accuracy_test'] =\
        metrics.accuracy_score(y_test, y_test_pred)
    class_models[model_name]['Recall_train'] =\
        metrics.recall_score(y_train, y_train_pred, average='weighted')
    class_models[model_name]['Recall_test'] =\
        metrics.recall_score(y_test, y_test_pred, average='weighted')
    class_models[model_name]['Precision_train'] =\
        metrics.precision_score(y_train, y_train_pred, average='weighted')
    class_models[model_name]['Precision_test'] =\
        metrics.precision_score(y_test, y_test_pred, average='weighted')
    class_models[model_name]['F1_test'] =\
        metrics.f1_score(y_test, y_test_pred, average='weighted')
    class_models[model_name]['MCC_test'] =\
        metrics.matthews_corrcoef(y_test, y_test_pred)

# %% [markdown]
# - MCC 기준 정렬 및 색상 코딩 적용

# %%
class_metrics = pd.DataFrame.\
    from_dict(class_models, 'index')[['Accuracy_train', 'Accuracy_test',\
                                      'Recall_train', 'Recall_test',\
                                      'Precision_train', 'Precision_test',\
                                      'F1_test', 'MCC_test']]
with pd.option_context('display.precision', 3):
    html = class_metrics.sort_values(by='MCC_test', ascending=False).style.\
        background_gradient(cmap='plasma', low=0.43, high=0.63,\
                            subset=['Accuracy_train', 'Accuracy_test']).\
        background_gradient(cmap='viridis', low=0.63, high=0.43,
                            subset=['F1_test'])
html
# Out:
# <style  type="text/css" >
# #T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col0,#T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col1,#T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col0{
#             background-color:  #6e00a8;
#             color:  #f1f1f1;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col6{
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col1{
#             background-color:  #ef7c51;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col6{
#             background-color:  #75d054;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col0{
#             background-color:  #a31e9a;
#             color:  #f1f1f1;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col1{
#             background-color:  #ef7e50;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col6{
#             background-color:  #3dbc74;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col0{
#             background-color:  #7a02a8;
#             color:  #f1f1f1;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col1,#T_ef858dba_c055_11ee_ba60_035c043bd5f9row5_col0{
#             background-color:  #f1814d;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col6{
#             background-color:  #3bbb75;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col0{
#             background-color:  #6f00a8;
#             color:  #f1f1f1;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col1{
#             background-color:  #eb7655;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col6{
#             background-color:  #2eb37c;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row5_col1{
#             background-color:  #d04d73;
#             color:  #000000;
#         }#T_ef858dba_c055_11ee_ba60_035c043bd5f9row5_col6{
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }</style><table id="T_ef858dba_c055_11ee_ba60_035c043bd5f9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy_train</th>        <th class="col_heading level0 col1" >Accuracy_test</th>        <th class="col_heading level0 col2" >Recall_train</th>        <th class="col_heading level0 col3" >Recall_test</th>        <th class="col_heading level0 col4" >Precision_train</th>        <th class="col_heading level0 col5" >Precision_test</th>        <th class="col_heading level0 col6" >F1_test</th>        <th class="col_heading level0 col7" >MCC_test</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef858dba_c055_11ee_ba60_035c043bd5f9level0_row0" class="row_heading level0 row0" >decision_tree</th>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col0" class="data row0 col0" >0.497</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col1" class="data row0 col1" >0.464</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col2" class="data row0 col2" >0.497</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col3" class="data row0 col3" >0.464</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col4" class="data row0 col4" >0.541</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col5" class="data row0 col5" >0.494</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col6" class="data row0 col6" >0.441</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row0_col7" class="data row0 col7" >0.246</td>
#             </tr>
#             <tr>
#                         <th id="T_ef858dba_c055_11ee_ba60_035c043bd5f9level0_row1" class="row_heading level0 row1" >logistic</th>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col0" class="data row1 col0" >0.496</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col1" class="data row1 col1" >0.493</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col2" class="data row1 col2" >0.496</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col3" class="data row1 col3" >0.493</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col4" class="data row1 col4" >0.498</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col5" class="data row1 col5" >0.494</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col6" class="data row1 col6" >0.492</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row1_col7" class="data row1 col7" >0.232</td>
#             </tr>
#             <tr>
#                         <th id="T_ef858dba_c055_11ee_ba60_035c043bd5f9level0_row2" class="row_heading level0 row2" >gradient_boosting</th>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col0" class="data row2 col0" >0.622</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col1" class="data row2 col1" >0.494</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col2" class="data row2 col2" >0.622</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col3" class="data row2 col3" >0.494</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col4" class="data row2 col4" >0.633</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col5" class="data row2 col5" >0.488</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col6" class="data row2 col6" >0.481</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row2_col7" class="data row2 col7" >0.227</td>
#             </tr>
#             <tr>
#                         <th id="T_ef858dba_c055_11ee_ba60_035c043bd5f9level0_row3" class="row_heading level0 row3" >mlp</th>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col0" class="data row3 col0" >0.522</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col1" class="data row3 col1" >0.494</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col2" class="data row3 col2" >0.522</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col3" class="data row3 col3" >0.494</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col4" class="data row3 col4" >0.517</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col5" class="data row3 col5" >0.485</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col6" class="data row3 col6" >0.480</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row3_col7" class="data row3 col7" >0.223</td>
#             </tr>
#             <tr>
#                         <th id="T_ef858dba_c055_11ee_ba60_035c043bd5f9level0_row4" class="row_heading level0 row4" >lda</th>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col0" class="data row4 col0" >0.501</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col1" class="data row4 col1" >0.492</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col2" class="data row4 col2" >0.501</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col3" class="data row4 col3" >0.492</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col4" class="data row4 col4" >0.500</td>
#                         <td id="T_ef858dba_c055_11ee_ba60_035c043bd5f9row4_col5" class="data row4 col5" >0.489</td>
#                         <td id="T_ef858dba_c055_11e

# %%
print('NIR: %.4f' %\
      (y_train[y_train==1].shape[0]/y_train.shape[0]))
# Out:
# NIR: 0.4215

# %%
dt_imp_df = pd.DataFrame({\
                'name': X_train.columns,
                'dt_imp': class_models['decision_tree']['fitted'].\
                          feature_importances_})
gb_imp_df = pd.DataFrame({\
                'name': X_train.columns,
                'gb_imp': class_models['gradient_boosting']['fitted'].\
                          feature_importances_})
rf_imp_df = pd.DataFrame({\
                'name': X_train.columns,
                'rf_imp': class_models['random_forest']['fitted'].\
                         feature_importances_})

# %%
dt_rank_df = pd.DataFrame({'dt_rank':\
                           dt_imp_df['dt_imp'].\
                           rank(method='first',\
                                ascending=False).astype(int)})
gb_rank_df = pd.DataFrame({'gb_rank':\
                           gb_imp_df['gb_imp'].\
                           rank(method='first',\
                                ascending=False).astype(int)})
rf_rank_df = pd.DataFrame({'rf_rank':\
                           rf_imp_df['rf_imp'].\
                           rank(method='first',\
                                ascending=False).astype(int)})

# %%
tree_ranks_df = pd.merge(\
                    pd.merge(\
                        pd.concat((dt_imp_df, dt_rank_df), axis=1),\
                        pd.concat((gb_imp_df, gb_rank_df), axis=1),\
                        'left'),\
                    pd.concat((rf_imp_df, rf_rank_df), axis=1),\
                    'left')
tree_ranks_df['avg_rank'] = (tree_ranks_df['dt_rank'] +\
                            tree_ranks_df['gb_rank'] + \
                            tree_ranks_df['rf_rank'])/3
tree_ranks_df.sort_values(by='avg_rank')
# Out:
#                 name    dt_imp  dt_rank    gb_imp  gb_rank    rf_imp  rf_rank  \
# 28            birthn  0.851533        1  0.368877        1  0.196067        1
# 81        testelapse  0.013708        3  0.037157        2  0.027307        2
# 26               age  0.006679        7  0.030320        3  0.025065        3
# 0                 Q1  0.025340        2  0.025634        6  0.016135        6
# 80       introelapse  0.005056        9  0.030149        4  0.022142        5
# ..               ...       ...      ...       ...      ...       ...      ...
# 89        country_GB  0.000000       90  0.001118       91  0.002023       91
# 94     source_google  0.000000       95  0.000541       96  0.003204       82
# 91        country_NZ  0.000000       92  0.001134       90  0.000690       93
# 83  gender_undefined  0.000000       87  0.000684       94  0.000241       96
# 90        country_IE  0.000000       91  0.001082       92  0.000577       95
#
#      avg_rank
# 28   1.000000
# 81   2.333333
# 26   4.333333
# 0    4.666667
# 80   6.000000
# ..        ...
# 89  90.666667
# 94  91.000000
# 91  91.666667
# 83  92.333333
# 90  92.666667
#
# [96 rows x 8 columns]

# %%
print(class_models['logistic']['fitted'].coef_.shape)
# Out:
# (3, 96)

# %%
stdv = np.std(X_train, 0)
lr_imp_df = pd.DataFrame({\
                'name': X_train.columns,\
                'first_coef_norm':\
                          class_models['logistic']['fitted'].coef_[0] * stdv,\
                'middle_coef_norm':\
                          class_models['logistic']['fitted'].coef_[1] * stdv,\
                'last_coef_norm':\
                          class_models['logistic']['fitted'].coef_[2] * stdv}).\
            reset_index(drop=True)

# %%
class_priors = class_models['lda']['fitted'].priors_
print(class_priors)
# Out:
# [0.42147566 0.23701862 0.34150572]

# %%
lr_imp_df['coef_weighted_avg'] = (abs(lr_imp_df['first_coef_norm']) * class_priors[0]) +\
                                 (abs(lr_imp_df['middle_coef_norm']) * class_priors[1]) +\
                                 (abs(lr_imp_df['last_coef_norm']) * class_priors[2])

# %%
lr_imp_df.\
    sort_values(by='coef_weighted_avg', ascending=False).style.\
    background_gradient(cmap='viridis', low=-0.1, high=0.1,\
                        subset=['first_coef_norm',\
                                'middle_coef_norm', 'last_coef_norm'])
# Out:
# <style  type="text/css" >
# #T_fd390ee6_c055_11ee_ba60_035c043bd5f9row0_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row0_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row1_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row2_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row3_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row4_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row5_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row6_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row7_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row8_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row9_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row10_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row11_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row12_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row13_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row14_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row15_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row16_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row17_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row18_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row19_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row20_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row21_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row22_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row23_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row24_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row25_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row26_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row27_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row28_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row29_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row30_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row31_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row32_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row33_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row34_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row35_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row36_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row37_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row38_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row39_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row40_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row41_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row42_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row43_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row44_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row45_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row46_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row47_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row48_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row49_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row50_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row51_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row52_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row53_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row54_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row55_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row56_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row57_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row58_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row59_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row60_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row61_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row62_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row63_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row64_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row65_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row66_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row67_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row68_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row69_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row70_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row71_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row72_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row73_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row74_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row75_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row76_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row77_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row78_col2,#T_fd390ee6 ...
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row0_col2,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row1_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row13_col3{
#             background-color:  #bddf26;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row1_col3{
#             background-color:  #24878e;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row2_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row4_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row48_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row64_col3{
#             background-color:  #95d840;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row2_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row57_col1{
#             background-color:  #2fb47c;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row3_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row42_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row70_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row78_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row82_col3{
#             background-color:  #7cd250;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row3_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row19_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row34_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row36_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row39_col1{
#             background-color:  #54c568;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row4_col1{
#             background-color:  #1fa187;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row5_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row46_col1{
#             background-color:  #50c46a;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row5_col3{
#             background-color:  #bade28;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row6_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row8_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row8_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row46_col3{
#             background-color:  #70cf57;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row6_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row35_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row78_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row87_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row89_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row90_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row91_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row92_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row93_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row94_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row95_col1{
#             background-color:  #3fbc73;
#             color:  #000000;
#         }#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row7_col1,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row73_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row75_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row80_col3,#T_fd390ee6_c055_11ee_ba60_035c043bd5f9row83_col3,#T_

# %%
class_models['lda']['fitted'].coef_.shape
# Out:
# (3, 96)

# %%
lda_imp_df = pd.DataFrame({\
                'name': X_train.columns,\
                'first_coef_norm':\
                          class_models['lda']['fitted'].coef_[0] * stdv,\
                'middle_coef_norm':\
                          class_models['lda']['fitted'].coef_[1] * stdv,\
                'last_coef_norm':\
                          class_models['lda']['fitted'].coef_[2] * stdv}).\
            reset_index(drop=True)

# %%
lda_imp_df['coef_weighted_avg'] = (abs(lda_imp_df['first_coef_norm']) * class_priors[0]) +\
                                 (abs(lda_imp_df['middle_coef_norm']) * class_priors[1]) +\
                                 (abs(lda_imp_df['last_coef_norm']) * class_priors[2])

# %%
lda_imp_df.\
    sort_values(by='coef_weighted_avg', ascending=False).style.\
    background_gradient(cmap='viridis', low=-0.1, high=0.1,\
                        subset=['first_coef_norm',\
                                'middle_coef_norm', 'last_coef_norm'])
# Out:
# <style  type="text/css" >
# #T_0fff03c8_c056_11ee_ba60_035c043bd5f9row0_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row0_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row1_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row2_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row3_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row4_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row6_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row7_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row8_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row9_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row10_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row11_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row12_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row13_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row14_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row15_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row16_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row17_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row18_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row19_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row20_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row21_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row22_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row23_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row24_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row25_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row26_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row27_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row28_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row29_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row30_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row31_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row32_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row33_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row34_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row35_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row36_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row37_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row38_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row39_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row40_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row41_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row42_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row43_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row44_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row45_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row46_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row47_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row48_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row49_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row50_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row51_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row52_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row53_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row54_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row55_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row56_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row57_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row58_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row59_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row60_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row61_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row62_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row63_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row64_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row65_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row66_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row67_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row68_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row69_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row70_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row71_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row72_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row73_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row74_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row75_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row76_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row77_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row78_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row79_col2,#T_0fff03c ...
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row0_col2,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row1_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row3_col3{
#             background-color:  #bddf26;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row1_col3{
#             background-color:  #23888e;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row2_col1{
#             background-color:  #86d549;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row2_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row23_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row33_col1{
#             background-color:  #28ae80;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row3_col1{
#             background-color:  #20a386;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row4_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row14_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row41_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row82_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row87_col3{
#             background-color:  #69cd5b;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row4_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row25_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row34_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row43_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row86_col1{
#             background-color:  #3fbc73;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row5_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row48_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row88_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row89_col1{
#             background-color:  #35b779;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row5_col2{
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row5_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row22_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row35_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row39_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row54_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row56_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row57_col1{
#             background-color:  #2db27d;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row6_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row18_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row80_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row94_col3{
#             background-color:  #65cb5e;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row6_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row10_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row50_col1,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row75_col1{
#             background-color:  #31b57b;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row7_col1{
#             background-color:  #21a685;
#             color:  #000000;
#         }#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row7_col3,#T_0fff03c8_c056_11ee_ba60_035c043bd5f9row33

# %%
print(class_models['mlp']['fitted'][1].coefs_[0].shape)
print(class_models['mlp']['fitted'][1].coefs_[1].shape)
# Out:
# (96, 11)
# (11, 3)

# %%
for model_name in class_models.keys():
    fitted_model = class_models[model_name]['fitted']
    permutation_imp = inspection.permutation_importance(\
                        fitted_model, X_test, y_test, n_jobs=-1,\
                        scoring='accuracy', n_repeats=8,\
                        random_state=rand)
    class_models[model_name]['importances_mean'] =\
                        permutation_imp.importances_mean

# %%
perm_imp_df = pd.DataFrame({
                'name': X_train.columns,\
                'dt_imp': class_models['decision_tree']['importances_mean'],\
                'gb_imp': class_models['gradient_boosting']['importances_mean'],\
                'rf_imp': class_models['random_forest']['importances_mean'],\
                'log_imp': class_models['logistic']['importances_mean'],\
                'lda_imp': class_models['lda']['importances_mean'],\
                'mlp_imp': class_models['mlp']['importances_mean']}).\
            reset_index(drop=True)

# %%
perm_imp_df['avg_imp'] = (perm_imp_df['dt_imp'] + perm_imp_df['gb_imp'] +\
                         perm_imp_df['rf_imp'] + perm_imp_df['log_imp'] +\
                         perm_imp_df['lda_imp'] + perm_imp_df['mlp_imp'])/6

# %%
perm_imp_sorted_df = perm_imp_df.round(5).\
    sort_values(by='avg_imp', ascending=False)
perm_imp_sorted_df.style.\
    background_gradient(cmap='viridis_r', low=0, high=0.2,\
                        subset=['dt_imp', 'gb_imp', 'rf_imp',\
                                'log_imp', 'lda_imp', 'mlp_imp'])
# Out:
# <style  type="text/css" >
# #T_51db97e8_c056_11ee_ba60_035c043bd5f9row0_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row0_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row0_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row0_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row0_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row0_col6{
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row1_col1{
#             background-color:  #d5e21a;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row1_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row4_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row6_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row45_col3{
#             background-color:  #e2e418;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row1_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row7_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row9_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row9_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row11_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row17_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row20_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row21_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row25_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row25_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row31_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row35_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row47_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row55_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row58_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row59_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row77_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row78_col5{
#             background-color:  #eae51a;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row1_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row1_col6{
#             background-color:  #cde11d;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row1_col5{
#             background-color:  #aadc32;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row2_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row2_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row3_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row5_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row8_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row8_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row9_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row9_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row10_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row11_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row11_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row12_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row13_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row14_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row15_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row16_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row17_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row17_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row17_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row18_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row19_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row21_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row22_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row22_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row23_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row26_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row26_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row28_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row29_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row33_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row33_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row34_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row36_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row36_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row40_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row40_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row41_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row42_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row43_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row43_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row45_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row46_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row47_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row47_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row48_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row49_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row50_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row51_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row53_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row54_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row54_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row54_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row55_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row56_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row57_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row59_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row60_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row61_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row62_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row66_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row69_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row69_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row70_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row71_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row71_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row73_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row74_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row75_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row76_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row78_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row79_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row81_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row81_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row82_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row86_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row86_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row86_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row89_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row90_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row91_col6 ...
#             background-color:  #f1e51d;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row2_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row3_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row15_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row46_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row64_col3{
#             background-color:  #e5e419;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row2_col3{
#             background-color:  #d2e21b;
#             color:  #000000;
#         }#T_51db97e8_c056_11ee_ba60_035c043bd5f9row2_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row9_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row11_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row14_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row15_col3,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row23_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row24_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row27_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row27_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row28_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row36_col1,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row37_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row42_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row43_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row43_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row45_col5,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row46_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row47_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row47_col6,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row48_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row48_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row49_col2,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row50_col4,#T_51db97e8_c056_11ee_ba60_035c043bd5f9row5

# %%
pd.DataFrame.\
    from_dict(class_models, 'index')[['Accuracy_test']] -\
    perm_imp_sorted_df.iloc[0,1:7].to_numpy().reshape((6,1))
# Out:
#                   Accuracy_test
# decision_tree          0.325639
# gradient_boosting       0.38837
# random_forest          0.409015
# logistic               0.379918
# lda                    0.408777
# mlp                    0.385114

# %%
feature_names = ['birthn', 'Q1', 'Q13', 'age']
feature_labels = ['# of Births', 'Question #1',\
                  'Question #13', 'Age']

# %%
for i in range(len(feature_names)):
    pdp_feat_df = pdp.pdp_isolate(\
        model=class_models['gradient_boosting']['fitted'],\
        dataset=pd.concat((X_test, y_test), axis=1),\
        model_features=X_test.columns,\
        feature=feature_names[i]
    )
    fig, axes = pdp.pdp_plot(
        pdp_isolate_out=pdp_feat_df, center=True,\
        x_quantile=True, ncols=3, plot_lines=True,\
        frac_to_plot=100, figsize=(15,6),\
        feature_name=feature_labels[i]
    )
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
birthorder_abbrev_df = birthorder_df[['age', 'birthorder']]
birthorder_abbrev_df.set_index(pd.cut(\
                                  birthorder_abbrev_df['age'],\
                                  [12, 16, 18, 20, 22, 26, 30,\
                                   36, 46, 88]), inplace=True)
agegroup_birthorder_counts_s = birthorder_abbrev_df.\
                            groupby([birthorder_abbrev_df.index,\
                                     'birthorder']).size()
agegroup_counts_s = birthorder_abbrev_df.groupby(\
                                            birthorder_abbrev_df.index)\
                                            ['birthorder'].count()
agegroup_pct_birthorder_s = agegroup_birthorder_counts_s.div(\
                                                    agegroup_counts_s,\
                                                     axis=0,level=0)
agegroup_pct_birthorder_s.unstack().plot.bar(stacked=True,\
                                         figsize=(15,8))

# %%
pdp_birthn_Q1_df = pdp.pdp_interact(
    model=class_models['random_forest']['fitted'],\
    dataset=pd.concat((X_test, y_test), axis=1),\
    model_features=X_test.columns, features=['birthn','Q1'],\
    n_jobs=-1
)
fig, axes = pdp.pdp_interact_plot(
    pdp_interact_out=pdp_birthn_Q1_df,\
    plot_type='grid', x_quantile=True,\
    ncols=2, figsize=(15,15),\
    feature_names=['# of Births','Question #1']
)
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
pdp_age_testelapse_df = pdp.pdp_interact(
    model=class_models['random_forest']['fitted'],\
    dataset=pd.concat((X_test, y_test), axis=1),\
    model_features=X_test.columns, features=['age','testelapse'],\
    n_jobs=-1
)
fig, axes = pdp.pdp_interact_plot(
    pdp_interact_out=pdp_age_testelapse_df,\
    plot_type='contour', x_quantile=True,\
    ncols=2, figsize=(15,15),\
    feature_names=['Age','Time taking test (minutes)']
)

# %%
np.random.seed(rand)
sample_size = 0.1
sample_idx = np.random.choice(\
                    X_test.shape[0],\
                    math.ceil(X_test.shape[0]*sample_size),\
                    replace=False)
X_test_samp = X_test.iloc[sample_idx,:]

# %%
def predict_prob_first_born(test_df):
    return class_models['random_forest']['fitted'].\
                                predict_proba(test_df)[:,0]
def predict_prob_middle_child(test_df):
    return class_models['random_forest']['fitted'].\
                                predict_proba(test_df)[:,1]
def predict_prob_last_born(test_df):
    return class_models['random_forest']['fitted'].\
                                predict_proba(test_df)[:,2]

# %%
legend_key = {0:'N/A', 1:'Disagree', 2:'Somewhat Disagree',
              3:'Neutral', 4:'Somewhat Agree', 5:'Agree'}

# %%
mldatasets.plot_data_vs_ice(predict_prob_first_born,\
                            'Probability of Firstborn',\
                            X=X_test_samp, feature_name='birthn',\
                            feature_label='# of Births',\
                            color_by='Q1', legend_key=legend_key)

# %%
mldatasets.plot_data_vs_ice(predict_prob_middle_child,\
                            'Probability of Middle Child',\
                            X=X_test_samp, feature_name='birthn',\
                            feature_label='# of Births',\
                            color_by='Q1', legend_key=legend_key)

# %%
mldatasets.plot_data_vs_ice(predict_prob_last_born,\
                            'Probability of Lastborn',\
                            X=X_test_samp, feature_name='birthn',\
                            feature_label='# of Births',\
                            color_by='Q1', legend_key=legend_key)
